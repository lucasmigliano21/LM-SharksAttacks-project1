# %%
import pandas as pd
import numpy as np
import re

sharks=pd.read_csv('attacks.csv', encoding='latin2')
pd.set_option('display.max_columns', None)
sharks.head(20)
# Out:
#      Case Number                  Date    Year          Type       Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks.shape
# Out:
# (25723, 24)

# %%
sharks.columns = sharks.columns.str.replace(' ', '')

sharks.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               Injury Fatal(Y/N)  \
# ...

# %%
sharks.rename({'CaseNumber.1': 'CaseNumber_1'}, axis=1)
# Out:
#        CaseNumber         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharks.columns = sharks.columns.str.replace('.', '_')
sharks.columns = sharks.columns.str.replace(':', '_')
sharks.head()
# Out:
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_12645/1092814882.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sharks.columns = sharks.columns.str.replace('.', '_')
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# ...

# %%
sharks.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CaseNumber            8702 non-null   object
#  1   Date                  6302 non-null   object
#  2   Year                  6300 non-null   float64
#  3   Type                  6298 non-null   object
#  4   Country               6252 non-null   object
#  5   Area                  5847 non-null   object
#  6   Location              5762 non-null   object
#  7   Activity              5758 non-null   object
#  8   Name                  6092 non-null   object
#  9   Sex                   5737 non-null   object
#  10  Age                   3471 non-null   object
#  11  Injury                6274 non-null   object
#  12  Fatal(Y/N)            5763 non-null   object
#  13  Time                  2948 non-null   object
#  14  Species               3464 non-null   object
# ...

# %%
sharks.count()
# Out:
# CaseNumber              8702
# Date                    6302
# Year                    6300
# Type                    6298
# Country                 6252
# Area                    5847
# Location                5762
# Activity                5758
# Name                    6092
# Sex                     5737
# Age                     3471
# Injury                  6274
# Fatal(Y/N)              5763
# Time                    2948
# Species                 3464
# InvestigatororSource    6285
# pdf                     6302
# hrefformula             6301
# href                    6302
# CaseNumber_1            6302
# CaseNumber_2            6302
# originalorder           6309
# Unnamed_22                 1
# Unnamed_23                 2
# dtype: int64

# %%
sharks.Injury.unique()
# Out:
# array(['No injury to occupant, outrigger canoe and paddle damaged',
#        'Minor injury to left thigh',
#        'Injury to left lower leg from surfboard skeg', ...,
#        'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
sharks.Country.value_counts()
# Out:
# USA                       2229
# AUSTRALIA                 1338
# SOUTH AFRICA               579
# PAPUA NEW GUINEA           134
# NEW ZEALAND                128
#                           ...
# MALDIVE ISLANDS              1
# NICARAGUA                    1
# NORTH SEA                    1
# RED SEA / INDIAN OCEAN       1
# CEYLON (SRI LANKA)           1
# Name: Country, Length: 212, dtype: int64

# %%
sharks.dtypes
# Out:
# CaseNumber               object
# Date                     object
# Year                    float64
# Type                     object
# Country                  object
# Area                     object
# Location                 object
# Activity                 object
# Name                     object
# Sex                      object
# Age                      object
# Injury                   object
# Fatal(Y/N)               object
# Time                     object
# Species                  object
# InvestigatororSource     object
# pdf                      object
# hrefformula              object
# href                     object
# CaseNumber_1             object
# CaseNumber_2             object
# originalorder           float64
# Unnamed_22               object
# Unnamed_23               object
# dtype: object

# %%
sharks.Year.head()
# Out:
# 0    2018.0
# 1    2018.0
# 2    2018.0
# 3    2018.0
# 4    2018.0
# Name: Year, dtype: float64

# %%
nan_cols=sharks.isna().sum()

nan_cols[nan_cols>0]
# Out:
# CaseNumber              17021
# Date                    19421
# Year                    19423
# Type                    19425
# Country                 19471
# Area                    19876
# Location                19961
# Activity                19965
# Name                    19631
# Sex                     19986
# Age                     22252
# Injury                  19449
# Fatal(Y/N)              19960
# Time                    22775
# Species                 22259
# InvestigatororSource    19438
# pdf                     19421
# hrefformula             19422
# href                    19421
# CaseNumber_1            19421
# CaseNumber_2            19421
# originalorder           19414
# Unnamed_22              25722
# Unnamed_23              25721
# dtype: int64

# %% [markdown]
# # Species, Age, Time

# %%
cat_df=sharks.select_dtypes(include=['object'])
cat_df.columns
# Out:
# Index(['CaseNumber', 'Date', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal(Y/N)', 'Time', 'Species',
#        'InvestigatororSource', 'pdf', 'hrefformula', 'href', 'CaseNumber_1',
#        'CaseNumber_2', 'Unnamed_22', 'Unnamed_23'],
#       dtype='object')

# %%
sharks['Species']
# Out:
# 0            White shark
# 1                    NaN
# 2                    NaN
# 3              2 m shark
# 4        Tiger shark, 3m
#               ...
# 25718                NaN
# 25719                NaN
# 25720                NaN
# 25721                NaN
# 25722                NaN
# Name: Species, Length: 25723, dtype: object

# %%
sharks['Time']
# Out:
# 0                18h00
# 1        14h00  -15h00
# 2                07h45
# 3                  NaN
# 4                  NaN
#              ...
# 25718              NaN
# 25719              NaN
# 25720              NaN
# 25721              NaN
# 25722              NaN
# Name: Time, Length: 25723, dtype: object

# %%
df1 = sharks[['Species','Age','Time','Type','Country','Area','Location','Activity','Name','Injury',
              'Fatal(Y/N)','InvestigatororSource','pdf','hrefformula']]
df1
# Out:
#                Species  Age           Time        Type    Country  \
# 0          White shark   57          18h00     Boating        USA
# 1                  NaN   11  14h00  -15h00  Unprovoked        USA
# 2                  NaN   48          07h45     Invalid        USA
# 3            2 m shark  NaN            NaN  Unprovoked  AUSTRALIA
# 4      Tiger shark, 3m  NaN            NaN    Provoked     MEXICO
# ...                ...  ...            ...         ...        ...
# 25718              NaN  NaN            NaN         NaN        NaN
# 25719              NaN  NaN            NaN         NaN        NaN
# 25720              NaN  NaN            NaN         NaN        NaN
# 25721              NaN  NaN            NaN         NaN        NaN
# 25722              NaN  NaN            NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# ...

# %% [markdown]
# ··Reemplazo los nulos por unknown··

# %%
sharks[['CaseNumber', 'CaseNumber_1', 'CaseNumber_2','href','Date','Year','Species','Age','Time','Type','Country','Area','Location','Activity','Name','Injury','Sex',
              'Fatal(Y/N)','InvestigatororSource','pdf','hrefformula']]=sharks[['CaseNumber','CaseNumber_1', 'CaseNumber_2','href','Date','Year','Species','Age','Time','Type','Country','Area','Location','Activity','Name','Injury',
              'Sex','Fatal(Y/N)','InvestigatororSource','pdf','hrefformula']].fillna('unknown')

# %%
sharks.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
# ...

# %% [markdown]
# ··Comprobar que todos los valores nulos de las columnas seleccionadas se hayan convertido a "unknown"

# %%
nan_cols=sharks.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Unnamed_22    25722
# Unnamed_23    25721
# dtype: int64

# %%
sharks.count()
# Out:
# CaseNumber              25723
# Date                    25723
# Year                    25723
# Type                    25723
# Country                 25723
# Area                    25723
# Location                25723
# Activity                25723
# Name                    25723
# Sex                     25723
# Age                     25723
# Injury                  25723
# Fatal(Y/N)              25723
# Time                    25723
# Species                 25723
# InvestigatororSource    25723
# pdf                     25723
# hrefformula             25723
# href                    25723
# CaseNumber_1            25723
# CaseNumber_2            25723
# originalorder           25723
# Unnamed_22                  1
# Unnamed_23                  2
# dtype: int64

# %%
sharks.dropna(axis=0,how='all')
# Out:
#        CaseNumber         Date     Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018   2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018   2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018   2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018   2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018   2018.0    Provoked     MEXICO
# ...           ...          ...      ...         ...        ...
# 25718     unknown      unknown  unknown     unknown    unknown
# 25719     unknown      unknown  unknown     unknown    unknown
# 25720     unknown      unknown  unknown     unknown    unknown
# 25721     unknown      unknown  unknown     unknown    unknown
# 25722           0      unknown  unknown     unknown    unknown
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharks.originalorder.dtype
# Out:
# dtype('int64')

# %%
sharks[['originalorder']]=sharks[['originalorder']].fillna(0)

# %%
sharks['originalorder'].unique()
# Out:
# array([6303, 6302, 6301, ..., 6309, 6310,    0])

# %%
sharks['originalorder'] = sharks['originalorder'].apply(np.int64)

# %%
sharks['originalorder'].dtype
# Out:
# dtype('int64')

# %%
sharks.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
# ...

# %% [markdown]
# Quiero averiguar qué datos hay en las columnas de Unnamed ya que me trae que tienen 1 y 2 datos:

# %%
sharks['Unnamed_22'].unique()
# Out:
# array([nan, 'stopped here'], dtype=object)

# %%
sharks['Unnamed_23'].unique()
# Out:
# array([nan, 'Teramo', 'change filename'], dtype=object)

# %% [markdown]
# Puesto que son valores que no tienen relación con el dataset, los puedo transformar en unknown y luego lo repito para todos los valores nulos de la columna:

# %%
sharks[['Unnamed_22','Unnamed_23']]=sharks[['Unnamed_22','Unnamed_23']].fillna('unknown')

# %%
sharks.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
# ...

# %%
sharks.Unnamed_22=sharks.Unnamed_22.str.replace('stopped here', 'unknown')

# %%
sharks.Unnamed_22.unique()
# Out:
# array(['unknown'], dtype=object)

# %%
sharks.Unnamed_23=sharks.Unnamed_23.str.replace('Teramo', 'unknown')

# %%
sharks.Unnamed_23=sharks.Unnamed_23.str.replace('change filename', 'unknown')

# %%
sharks.Unnamed_23.unique()
# Out:
# array(['unknown'], dtype=object)

# %% [markdown]
# Ambas columnas fueron editadas para que contengan valores 'unknown' ya que los que traía el dataset no tenían sentido

# %%
sharks.CaseNumber_1.dtype
# Out:
# dtype('O')

# %%
sharks.CaseNumber.value_counts()
# Out:
# 0               2400
# 1920.00.00.b       2
# 1966.12.26         2
# 2014.08.02         2
# 1990.05.10         2
#                 ...
# 1999.09.05         1
# 1999.09.10         1
# 1999.09.16         1
# 1999.09.18         1
# xx                 1
# Name: CaseNumber, Length: 6287, dtype: int64

# %% [markdown]
# Como hay fechas iguales pero con una letra agregada, vamos a borrar ese patrón de las filas que lo contengan:

# %%
sharks.CaseNumber=sharks.CaseNumber.str.replace('.a', '')
# Out:
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_12645/501745692.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sharks.CaseNumber=sharks.CaseNumber.str.replace('.a', '')

# %%
sharks.CaseNumber=sharks.CaseNumber.str.replace('.b', '')
# Out:
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_12645/3270724606.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sharks.CaseNumber=sharks.CaseNumber.str.replace('.b', '')

# %%
sharks.CaseNumber=sharks.CaseNumber.str.replace('.c', '')
# Out:
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_12645/3034835292.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sharks.CaseNumber=sharks.CaseNumber.str.replace('.c', '')

# %%
sharks.CaseNumber=sharks.CaseNumber.str.replace('.R', '')
# Out:
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_12645/858126582.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sharks.CaseNumber=sharks.CaseNumber.str.replace('.R', '')

# %%
sharks.CaseNumber.value_counts()
# Out:
# 0             2400
# 1898.00.00       4
# 1904.00.00       4
# 1923.00.00       4
# 1929.00.00       3
#               ...
# 1993.10.10       1
# 1993.10.26       1
# 1993.10.30       1
# 1993.11.00       1
# xx               1
# Name: CaseNumber, Length: 5477, dtype: int64

# %% [markdown]
# La fila con 'xx' no nos va a dejar transformar la columna a datetime, por lo tanto la reemplazamos por un '0'

# %%
sharks.CaseNumber=sharks.CaseNumber.str.replace('xx', '0')

# %%
sharks.CaseNumber.value_counts()
# Out:
# 0             2401
# 1904.00.00       4
# 1923.00.00       4
# 1898.00.00       4
# 1960.00.00       3
#               ...
# 1993.10.26       1
# 1993.10.30       1
# 1993.11.00       1
# 1993.11.12       1
# 1974.09.14       1
# Name: CaseNumber, Length: 5476, dtype: int64

# %% [markdown]
# # BONUS

# %%
sharks2=sharks.drop_duplicates()

# %%
sharks2.shape
# Out:
# (6311, 24)

# %%
sharks2.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
# ...

# %%
import pylab as plt
import seaborn as sns
# %matplotlib inline  

plt.figure(figsize=(100, 60))
plt.ylabel('Attacks')
plt.xlabel('Countries')
sharks2.Country.value_counts().plot.bar();

# %% [markdown]
# USA es el país que más ataques recibió por partes de los tiburones.

# %%
plt.figure(figsize=(100, 60))
plt.ylabel('Attacks')
plt.xlabel('Sex')
sharks2.Sex.value_counts().plot.bar();

# %% [markdown]
# Los tiburones atacan, en su mayoría, a hombres
