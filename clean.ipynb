# %%
import pandas as pd
import numpy as np
import re

df_all=pd.read_csv('attacks.csv', encoding='latin2')
pd.set_option('display.max_columns', None)
sharks= df_all.copy()
sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks.shape

# %%
sharks.columns = sharks.columns.str.strip().str.replace(':', '').str.replace('.', '').str.replace(' ','_')

sharks.head()
# Out:
# /var/folders/y9/1ck368zx5tq778d5611f3syw0000gn/T/ipykernel_15149/3531605090.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sharks.columns = sharks.columns.str.strip().str.replace(':', '').str.replace('.', '').str.replace(' ','_')
#   Case_Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               Injury Fatal_(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time          Species          Investigator_or_Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case_Number1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   Case_Number2  original_order Unnamed_22 Unnamed_23
# 0   2018.06.25          6303.0        NaN        NaN
# 1   2018.06.18          6302.0        NaN        NaN
# 2   2018.06.09          6301.0        NaN        NaN
# 3   2018.06.08          6300.0        NaN        NaN
# 4   2018.06.04          6299.0        NaN        NaN

# %%
sharks.rename(columns = {'Fatal_(Y/N)' : 'Fatal'}, inplace = True)

# %%
sharks.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case_Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal                   5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator_or_Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href_formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case_Number1            6302 non-null   object
#  20  Case_Number2            6302 non-null   object
#  21  original_order          6309 non-null   float64
#  22  Unnamed_22              1 non-null      object
#  23  Unnamed_23              2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 22.9 MB

# %% [markdown]
# Count to check how much valid values we have per column

# %%
sharks.count()
# Out:
# Case_Number               8702
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Location                  5762
# Activity                  5758
# Name                      6092
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal                     5763
# Time                      2948
# Species                   3464
# Investigator_or_Source    6285
# pdf                       6302
# href_formula              6301
# href                      6302
# Case_Number1              6302
# Case_Number2              6302
# original_order            6309
# Unnamed_22                   1
# Unnamed_23                   2
# dtype: int64

# %%
nan_cols=sharks.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Case_Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal                     19960
# Time                      22775
# Species                   22259
# Investigator_or_Source    19438
# pdf                       19421
# href_formula              19422
# href                      19421
# Case_Number1              19421
# Case_Number2              19421
# original_order            19414
# Unnamed_22                25722
# Unnamed_23                25721
# dtype: int64

# %% [markdown]
# # Replacing values

# %%
cat_df=sharks.select_dtypes(include=['object'])
cat_df.columns
# Out:
# Index(['Case_Number', 'Date', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Time', 'Species',
#        'Investigator_or_Source', 'pdf', 'href_formula', 'href', 'Case_Number1',
#        'Case_Number2', 'Unnamed_22', 'Unnamed_23'],
#       dtype='object')

# %%
sharks['Species']
# Out:
# 0            White shark
# 1                    NaN
# 2                    NaN
# 3              2 m shark
# 4        Tiger shark, 3m
#               ...
# 25718                NaN
# 25719                NaN
# 25720                NaN
# 25721                NaN
# 25722                NaN
# Name: Species, Length: 25723, dtype: object

# %%
sharks['Time']
# Out:
# 0                18h00
# 1        14h00  -15h00
# 2                07h45
# 3                  NaN
# 4                  NaN
#              ...
# 25718              NaN
# 25719              NaN
# 25720              NaN
# 25721              NaN
# 25722              NaN
# Name: Time, Length: 25723, dtype: object

# %% [markdown]
# ··Reemplazo los nulos por unknown··

# %%
sharks[['Case_Number', 'Date', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Time', 'Species',
       'Investigator_or_Source', 'pdf', 'href_formula', 'href', 'Case_Number1',
       'Case_Number2']]=sharks[['Case_Number', 'Date', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Time', 'Species',
       'Investigator_or_Source', 'pdf', 'href_formula', 'href', 'Case_Number1',
       'Case_Number2']].fillna('unknown')

# %%
sharks.head()
# Out:
#   Case_Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
#                                               Injury Fatal           Time  \
# 0  No injury to occupant, outrigger canoe and pad...     N          18h00
# 1                         Minor injury to left thigh     N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg     N          07h45
# 3                          Minor injury to lower leg     N        unknown
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT     N        unknown
#
#            Species          Investigator_or_Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1          unknown  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2          unknown  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case_Number1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   Case_Number2  original_order Unnamed_22 Unnamed_23
# 0   2018.06.25          6303.0        NaN        NaN
# 1   2018.06.18          6302.0        NaN        NaN
# 2   2018.06.09          6301.0        NaN        NaN
# 3   2018.06.08          6300.0        NaN        NaN
# 4   2018.06.04          6299.0        NaN        NaN

# %% [markdown]
# ··Comprobar que todos los valores nulos de las columnas seleccionadas se hayan convertido a "unknown"

# %%
nan_cols=sharks.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Year              19423
# original_order    19414
# Unnamed_22        25722
# Unnamed_23        25721
# dtype: int64

# %%
sharks.count()
# Out:
# Case_Number               25723
# Date                      25723
# Year                       6300
# Type                      25723
# Country                   25723
# Area                      25723
# Location                  25723
# Activity                  25723
# Name                      25723
# Sex                       25723
# Age                       25723
# Injury                    25723
# Fatal                     25723
# Time                      25723
# Species                   25723
# Investigator_or_Source    25723
# pdf                       25723
# href_formula              25723
# href                      25723
# Case_Number1              25723
# Case_Number2              25723
# original_order             6309
# Unnamed_22                    1
# Unnamed_23                    2
# dtype: int64

# %%
sharks.dropna(axis=0,how='all')
# Out:
#       Case_Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718     unknown      unknown     NaN     unknown    unknown
# 25719     unknown      unknown     NaN     unknown    unknown
# 25720     unknown      unknown     NaN     unknown    unknown
# 25721     unknown      unknown     NaN     unknown    unknown
# 25722          xx      unknown     NaN     unknown    unknown
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718          unknown                         unknown      unknown
# 25719          unknown                         unknown      unknown
# 25720          unknown                         unknown      unknown
# 25721          unknown                         unknown      unknown
# 25722          unknown                         unknown      unknown
#
#                   Name      Sex      Age  \
# 0          Julie Wolfe        F       57
# 1      Adyson McNeely         F       11
# 2          John Denges        M       48
# 3                 male        M  unknown
# 4       Gustavo Ramos         M  unknown
# ...                ...      ...      ...
# 25718          unknown  unknown  unknown
# 25719          unknown  unknown  unknown
# 25720          unknown  unknown  unknown
# 25721          unknown  unknown  unknown
# 25722          unknown  unknown  unknown
#
#                                                   Injury    Fatal  \
# 0      No injury to occupant, outrigger canoe and pad...        N
# 1                             Minor injury to left thigh        N
# 2           Injury to left lower leg from surfboard skeg        N
# 3                              Minor injury to lower leg        N
# 4      Lacerations to leg & hand shark PROVOKED INCIDENT        N
# ...                                                  ...      ...
# 25718                                            unknown  unknown
# 25719                                            unknown  unknown
# 25720                                            unknown  unknown
# 25721                                            unknown  unknown
# 25722                                            unknown  unknown
#
#                 Time          Species          Investigator_or_Source  \
# 0              18h00      White shark                R. Collier, GSAF
# 1      14h00  -15h00          unknown  K.McMurray, TrackingSharks.com
# 2              07h45          unknown  K.McMurray, TrackingSharks.com
# 3            unknown        2 m shark                  B. Myatt, GSAF
# 4            unknown  Tiger shark, 3m                       A .Kipper
# ...              ...              ...                             ...
# 25718        unknown          unknown                         unknown
# 25719        unknown          unknown                         unknown
# 25720        unknown          unknown                         unknown
# 25721        unknown          unknown                         unknown
# 25722        unknown          unknown                         unknown
#
#                             pdf  \
# 0          2018.06.25-Wolfe.pdf
# 1        2018.06.18-McNeely.pdf
# 2         2018.06.09-Denges.pdf
# 3      2018.06.08-Arrawarra.pdf
# 4          2018.06.04-Ramos.pdf
# ...                         ...
# 25718                   unknown
# 25719                   unknown
# 25720                   unknown
# 25721                   unknown
# 25722                   unknown
#
#                                             href_formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                            unknown
# 25719                                            unknown
# 25720                                            unknown
# 25721                                            unknown
# 25722                                            unknown
#
#                                                     href Case_Number1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
# ...                                                  ...          ...
# 25718                                            unknown      unknown
# 25719                                            unknown      unknown
# 25720                                            unknown      unknown
# 25721                                            unknown      unknown
# 25722                                            unknown      unknown
#
#       Case_Number2  original_order Unnamed_22 Unnamed_23
# 0       2018.06.25          6303.0        NaN        NaN
# 1       2018.06.18          6302.0        NaN        NaN
# 2       2018.06.09          6301.0        NaN        NaN
# 3       2018.06.08          6300.0        NaN        NaN
# 4       2018.06.04          6299.0        NaN        NaN
# ...            ...             ...        ...        ...
# 25718      unknown             NaN        NaN        NaN
# 25719      unknown             NaN        NaN        NaN
# 25720      unknown             NaN        NaN        NaN
# 25721      unknown             NaN        NaN        NaN
# 25722      unknown             NaN        NaN        NaN
#
# [25723 rows x 24 columns]

# %%
sharks[['original_order']]=sharks[['original_order']].fillna(0)

# %%
sharks['original_order'].unique()
# Out:
# array([6303., 6302., 6301., ..., 6309., 6310.,    0.])

# %%
sharks['original_order'] = sharks['original_order'].apply(np.int64)

# %%
sharks['original_order'].dtype
# Out:
# dtype('int64')

# %%
sharks.head()
# Out:
#   Case_Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
#                                               Injury Fatal           Time  \
# 0  No injury to occupant, outrigger canoe and pad...     N          18h00
# 1                         Minor injury to left thigh     N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg     N          07h45
# 3                          Minor injury to lower leg     N        unknown
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT     N        unknown
#
#            Species          Investigator_or_Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1          unknown  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2          unknown  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case_Number1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   Case_Number2  original_order Unnamed_22 Unnamed_23
# 0   2018.06.25            6303        NaN        NaN
# 1   2018.06.18            6302        NaN        NaN
# 2   2018.06.09            6301        NaN        NaN
# 3   2018.06.08            6300        NaN        NaN
# 4   2018.06.04            6299        NaN        NaN

# %% [markdown]
# Quiero averiguar qué datos hay en las columnas de Unnamed ya que me trae que tienen 1 y 2 datos:

# %%
sharks['Unnamed_22'].unique()
# Out:
# array([nan, 'stopped here'], dtype=object)

# %%
sharks['Unnamed_23'].unique()
# Out:
# array([nan, 'Teramo', 'change filename'], dtype=object)

# %% [markdown]
# Puesto que son valores que no tienen relación con el dataset, los puedo transformar en unknown y luego lo repito para todos los valores nulos de la columna:

# %%
sharks[['Unnamed_22','Unnamed_23']]=sharks[['Unnamed_22','Unnamed_23']].fillna('unknown')

# %%
sharks.head()
# Out:
#   Case_Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
#                                               Injury Fatal           Time  \
# 0  No injury to occupant, outrigger canoe and pad...     N          18h00
# 1                         Minor injury to left thigh     N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg     N          07h45
# 3                          Minor injury to lower leg     N        unknown
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT     N        unknown
#
#            Species          Investigator_or_Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1          unknown  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2          unknown  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case_Number1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   Case_Number2  original_order Unnamed_22 Unnamed_23
# 0   2018.06.25            6303    unknown    unknown
# 1   2018.06.18            6302    unknown    unknown
# 2   2018.06.09            6301    unknown    unknown
# 3   2018.06.08            6300    unknown    unknown
# 4   2018.06.04            6299    unknown    unknown

# %%
sharks.Unnamed_22=sharks.Unnamed_22.str.replace('stopped here', 'unknown')

# %%
sharks.Unnamed_22.unique()
# Out:
# array(['unknown'], dtype=object)

# %%
sharks.Unnamed_23=sharks.Unnamed_23.str.replace('Teramo', 'unknown')

# %%
sharks.Unnamed_23=sharks.Unnamed_23.str.replace('change filename', 'unknown')

# %%
sharks.Unnamed_23.unique()
# Out:
# array(['unknown'], dtype=object)

# %% [markdown]
# Ambas columnas fueron editadas para que contengan valores 'unknown' ya que los que traía el dataset no tenían sentido

# %%
sharks.Case_Number1.dtype
# Out:
# dtype('O')

# %%
sharks.Case_Number.value_counts()
# Out:
# unknown         17021
# 0                2400
# 1920.00.00.b        2
# 2009.12.18          2
# 1913.08.27.R        2
#                 ...
# 1999.09.04.b        1
# 1999.09.05          1
# 1999.09.10          1
# 1999.09.16          1
# xx                  1
# Name: Case_Number, Length: 6288, dtype: int64

# %% [markdown]
# Como hay fechas iguales pero con una letra agregada, vamos a borrar ese patrón de las filas que lo contengan:

# %%
sharks = sharks[sharks['Case_Number'].map(lambda x: len(str(x)) == 10)]

# %%
sharks.Case_Number.value_counts()
# Out:
# 2009.12.18    2
# 1980.07.00    2
# 1966.12.26    2
# 2005.04.06    2
# 1990.05.10    2
#              ..
# 1999.07.15    1
# 1999.07.06    1
# 1999.07.04    1
# 1999.07.03    1
# 0005.00.00    1
# Name: Case_Number, Length: 4039, dtype: int64

# %% [markdown]
# La fila con 'xx' no nos va a dejar transformar la columna a datetime, por lo tanto la reemplazamos por un '0'

# %%
sharks.Case_Number=sharks.Case_Number.str.replace('xx', '0')
# Out:
# /Users/lucasmigliano/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
sharks.Case_Number.value_counts()
# Out:
# 2009.12.18    2
# 1980.07.00    2
# 1966.12.26    2
# 2005.04.06    2
# 1990.05.10    2
#              ..
# 1999.07.15    1
# 1999.07.06    1
# 1999.07.04    1
# 1999.07.03    1
# 0005.00.00    1
# Name: Case_Number, Length: 4039, dtype: int64

# %%
sharks.to_csv('./clean_sharks.csv', index=False)

# %% [markdown]
# # BONUS

# %%
sharks2=sharks.drop_duplicates()

# %%
sharks2.shape
# Out:
# (4048, 24)

# %%
sharks2.head()
# Out:
#   Case_Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  unknown
#
#                                               Injury Fatal           Time  \
# 0  No injury to occupant, outrigger canoe and pad...     N          18h00
# 1                         Minor injury to left thigh     N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg     N          07h45
# 3                          Minor injury to lower leg     N        unknown
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT     N        unknown
#
#            Species          Investigator_or_Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1          unknown  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2          unknown  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case_Number1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   Case_Number2  original_order Unnamed_22 Unnamed_23
# 0   2018.06.25            6303    unknown    unknown
# 1   2018.06.18            6302    unknown    unknown
# 2   2018.06.09            6301    unknown    unknown
# 3   2018.06.08            6300    unknown    unknown
# 4   2018.06.04            6299    unknown    unknown

# %%
import pylab as plt
import seaborn as sns
# %matplotlib inline  

plt.figure(figsize=(100, 60))
plt.ylabel('Attacks')
plt.xlabel('Countries')
sharks2.Country.value_counts().plot.bar();

# %% [markdown]
# USA es el país que más ataques recibió por partes de los tiburones.

# %%
plt.figure(figsize=(100, 60))
plt.ylabel('Attacks')
plt.xlabel('Sex')
sharks2.Sex.value_counts().plot.bar();

# %% [markdown]
# Los tiburones atacan, en su mayoría, a hombres

# %%
plt.figure(figsize=(100, 60))
plt.ylabel('Attacks')
plt.xlabel('Year')
sharks2.Year.value_counts().plot.bar();

# %% [markdown]
# 2015 fue el año con mayor cantidad de ataques

# %%
plt.figure(figsize=(100, 60))
plt.ylabel('Attacks')
plt.xlabel('Fatality')
sharks2['Fatal'].value_counts().plot.bar();

# %% [markdown]
# More than twice of the attacks weren't fatal
